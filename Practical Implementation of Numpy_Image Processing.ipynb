# %%
import numpy as np

# %%
np.random.seed()
arr=np.random.randint(2,7,(4,4))

# %%
arr
# Out:
# array([[6, 6, 4, 5],
#        [2, 6, 6, 5],
#        [2, 5, 5, 3],
#        [6, 4, 6, 6]])

# %%
arr.reshape(2,-21)
# Out:
# array([[6, 6, 4, 5, 2, 6, 6, 5],
#        [2, 5, 5, 3, 6, 4, 6, 6]])

# %%
arr.T
# Out:
# array([[6, 2, 2, 6],
#        [6, 6, 5, 4],
#        [4, 6, 5, 6],
#        [5, 5, 3, 6]])

# %%
np.random.seed(20)
a=np.random.randint(2,5,(4,4))

# %%
a
# Out:
# array([[4, 2, 4, 3],
#        [2, 4, 4, 2],
#        [4, 2, 3, 4],
#        [4, 2, 3, 4]])

# %%
np.random.seed(30)
b=np.random.randn(4,4)

# %%
b
# Out:
# array([[-1.26405266,  1.52790535, -0.97071094,  0.47055962],
#        [-0.10069672,  0.30379318, -1.72596243,  1.58509537],
#        [ 0.13429659, -1.10685547,  1.57822555,  0.10749794],
#        [-0.76404783, -0.77518851,  1.38384717,  0.76038508]])

# %%
a*b #element wise
# Out:
# array([[-5.05621066,  3.0558107 , -3.88284375,  1.41167885],
#        [-0.20139343,  1.21517274, -6.90384971,  3.17019074],
#        [ 0.53718637, -2.21371093,  4.73467665,  0.42999177],
#        [-3.05619131, -1.55037702,  4.1515415 ,  3.04154034]])

# %%
np.dot(a,b) #dot product
# Out:
# array([[-7.0125612 , -0.03377962,  3.12967508,  7.76357623],
#        [-3.92180148, -1.70681544,  0.23532494,  9.23226265],
#        [-7.91090562,  0.29788734,  2.9352967 ,  8.41646337],
#        [-7.91090562,  0.29788734,  2.9352967 ,  8.41646337]])

# %% [markdown]
# ## Image Processing

# %%
from IPython.display import Image

# Replace 'Panda.jpeg' with the path to your image file
Image(filename="Panda.jpeg")

# %%
from matplotlib.image import imread
panda= imread("Panda.jpeg")
panda
# Out:
# array([[[48, 43, 40],
#         [48, 43, 40],
#         [48, 43, 40],
#         ...,
#         [ 4,  3,  0],
#         [ 4,  3,  0],
#         [ 4,  3,  0]],
#
#        [[48, 43, 40],
#         [48, 43, 40],
#         [48, 43, 40],
#         ...,
#         [ 4,  3,  0],
#         [ 4,  3,  0],
#         [ 4,  3,  0]],
#
#        [[48, 43, 40],
#         [48, 43, 40],
#         [48, 43, 40],
#         ...,
#         [ 4,  3,  0],
#         [ 4,  3,  0],
#         [ 4,  3,  0]],
#
#        ...,
#
#        [[24, 17, 11],
#         [24, 17, 11],
#         [24, 17, 11],
#         ...,
#         [19, 13, 15],
#         [20, 14, 16],
#         [22, 16, 18]],
#
#        [[24, 17, 11],
#         [24, 17, 11],
#         [24, 17, 11],
#         ...,
#         [18, 12, 14],
#         [19, 13, 15],
#         [20, 14, 16]],
#
#        [[24, 17, 11],
#         [24, 17, 11],
#         [24, 17, 11],
#         ...,
#         [18, 12, 14],
#         [18, 12, 14],
#         [19, 13, 15]]], dtype=uint8)

# %%
panda.shape, panda.size, panda.ndim
# Out:
# ((1366, 2048, 3), 8392704, 3)
